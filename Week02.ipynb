# %% [markdown]
# <a href="https://colab.research.google.com/github/IzzatunNauly/pcvk_genap_2023/blob/main/Week02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktikum

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Mechine Learning /kitten01.jfif')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi channer BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Mechine Learning /kitten01.jfif', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/Mechine Learning /kitten01.jfif', img5)

#tampilkan plot dengan ukuran canva yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,510),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R,G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # Pertanyaan
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut "from google.colab.patches import cv2_imshow
# from skimage import io"
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3

# %% [markdown]
# # Jawaban
# 1. Matplotlib dapat digunakan untuk melakukan visualisasi data secara 2D maupun 3D dan menghasilkan suatu gambar yang berkualitas bahkan dapat disimpan dengan format gambar seperti JPEG, JPG, dan PNG. Jika tidak menggunakan maplotlib maka tidak ada titik koordinatnya
# 2. Perbedaan antara tipe data int16 dan int 32
#
#   Int16
#
#       Ini adalah tipe FCL.
#
#       Dalam C #, pendek dipetakan ke Int16.
#
#       Ini adalah tipe nilai dan mewakili System.Int16 struct.
#
#       Itu ditandatangani dan membutuhkan 16 bit.
#
#       Ini memiliki minimum -32768 dan nilai maksimum +32767.
#
#   Int32
#
#       Ini adalah tipe FCL.
#
#       Dalam C #, int dipetakan ke Int32.
#
#       Ini adalah tipe nilai dan mewakili struct System.Int32.
#
#       Itu ditandatangani dan membutuhkan 32 bit.
#
#       Ini memiliki nilai minimum -2147483648 dan maksimum +2147483647.
#
# 3. kegunaan "google.colab.patches import cv2_imshow"
#
# - from google.colab.patches import cv2_imshow = menambahkan satu patches karena cv2.imshow tidak berjalan di Google Colab maupun Jupyter Notebook
#
# 4. kegunaan "skimage import io"
# - from skimage import io = melaksanakan tugas pemrosesan gambar atau buah librari pemrosesan gambar yang menerapkan algoritma dan utilitas untuk digunakan dalam penerapan riset, edukasi dan industri.

# %% [markdown]
# # Tugas
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :

# %% [markdown]
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?

# %% [markdown]
# --> figsize tidak mengubah ukuran image pixelnya namun hanya di zoom in atau zoom out

# %% [markdown]
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# %%
#2. -Tampilkan image dalam channel Red-Blue !
img_rg = img.copy()
img_rg[:,:,1] = 0
plt.imshow(img_rg)

# %%
#2. -Tampilkan image dalam channel Green-Blue !
img_rg = img.copy()
img_rg[:,:,0] = 0
plt.imshow(img_rg)

# %% [markdown]
# 3. Tampilkan image baris ke 20-115, kolom 25-120!

# %%
#3. Tampilkan image baris ke 20-115, kolom 20-120!
img_k = img[20:115,25:120]
plt.imshow(img_k)

# %% [markdown]
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %%
#3. Tampilkan image baris ke 5-30, semua kolom, channel red 
img_n = img[5:30,:,0]
plt.imshow(img_n)

# %% [markdown]
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
#4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!
imageWithRectangle = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(10,10))
cv.rectangle(imageWithRectangle, pt1=(0,0),pt2=(50,100),color=(255,255,255),thickness=5)
cv.rectangle(imageWithRectangle, pt1=(60,20),pt2=(100,100),color=(255,0,255),thickness=4)
cv.rectangle(imageWithRectangle, pt1=(200,250),pt2=(60,40),color=(0,255,255),thickness=3)
cv.rectangle(imageWithRectangle, pt1=(40,50),pt2=(80,80),color=(0,0,255),thickness=5)
cv.rectangle(imageWithRectangle, pt1=(100,30),pt2=(90,90),color=(255,0,0),thickness=5)
plt.imshow(imageWithRectangle)

# %% [markdown]
# 6. Tampilkan image dengan posisi terbalik!

# %%
#5. Tampilkan image dengan posisi terbalik!
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %% [markdown]
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).

# %%
#7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto)
img = cv.imread('/content/drive/MyDrive/Mechine Learning /izza.jpg')
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111)
cv.rectangle(img, pt1=(700,850), pt2=(500,600), color=(255, 0, 30), thickness = 5)
cv.circle(img, center=(600,800), radius=100, color=(180, 105, 255), thickness = 30)
ax.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %% [markdown]
# 8. Lengkapi tulisan nama file pada file citra dari soal no.7. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.

# %%
#8. Lengkapi tulisan nama file pada file citra dari soal no.7. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.
img = cv.imread('/content/drive/MyDrive/Mechine Learning /izza.jpg')
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111)
cv.rectangle(img, pt1=(700,850), pt2=(500,600), color=(255, 0, 30), thickness = 5)
cv.circle(img, center=(600,800), radius=100, color=(180, 105, 255), thickness = 30)
ax.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img,text='MY FAMILY',org=(10,500),fontFace=font,fontScale=4,color=(0,0,0),thickness=10,lineType=cv.LINE_AA)
plt.imshow(img)
